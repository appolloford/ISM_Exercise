# %% [markdown]
# <a href="https://colab.research.google.com/github/appolloford/ISM_Exercise/blob/main/ISM_Exercise_220407.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
IN_COLAB
# Out:
# True

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %% [markdown]
# ### Some practice of plotting figures

# %%
x = np.arange(100)
plt.plot(x, np.sin(x))

# %%
data = np.random.rand(100, 100)
plt.imshow(data)

# %% [markdown]
# ### Exercise: handle FUGIN data

# %%
if IN_COLAB:
    # Download data from URL. It may take some time
    cube = fits.open("https://github.com/appolloford/ISM_Exercise/raw/main/data/CloudR_IRAM30m_C18O21.fits")[0]
else:
    cube = fits.open("data/CloudR_IRAM30m_C18O21.fits")[0]

# %%
# Try to access the header

# %%
# Try to get one spectrum

# Plot the extracted spectrum

# %%
# Try to get the average spectrum from the full cube

# %%
# Try to get an integrated intensity map

# %%
# Advanced: Convert Spectra Channels to Velocity Channels
